# %% [markdown]
# # Chicago Crime Data Processing

# %% [markdown]
# ## 1. Aggregate to monthly count

# %%
import pandas as pd

# Read the CSV file into a pandas DataFrame
crime_df = pd.read_csv("/content/drive/MyDrive/MADS Capstone Team 23/Data/raw/CrimeData/Chicago/Chicago-CrimeData-2001-Presen.csv")

# %%
crime_df.head()
# Out:
#          ID Case Number                    Date                 Block  IUCR  \
# 0  11037294    JA371270  03/18/2015 12:00:00 PM     0000X W WACKER DR  1153
# 1  11646293    JC213749  12/20/2018 03:00:00 PM  023XX N LOCKWOOD AVE  1154
# 2  11645836    JC212333  05/01/2016 12:25:00 AM   055XX S ROCKWELL ST  1153
# 3  11645959    JC211511  12/20/2018 04:00:00 PM    045XX N ALBANY AVE  2820
# 4  11645601    JC212935  06/01/2014 12:01:00 AM   087XX S SANGAMON ST  1153
#
#          Primary Type                              Description  \
# 0  DECEPTIVE PRACTICE      FINANCIAL IDENTITY THEFT OVER $ 300
# 1  DECEPTIVE PRACTICE  FINANCIAL IDENTITY THEFT $300 AND UNDER
# 2  DECEPTIVE PRACTICE      FINANCIAL IDENTITY THEFT OVER $ 300
# 3       OTHER OFFENSE                         TELEPHONE THREAT
# 4  DECEPTIVE PRACTICE      FINANCIAL IDENTITY THEFT OVER $ 300
#
#   Location Description  Arrest  Domestic  ...  Ward  Community Area  FBI Code  \
# ...

# %%
crime_df.shape
# Out:
# (8100700, 22)

# %%
crime_df["Primary Type"].unique()
# Out:
# array(['DECEPTIVE PRACTICE', 'OTHER OFFENSE', 'THEFT', 'BATTERY',
#        'ASSAULT', 'WEAPONS VIOLATION', 'INTERFERENCE WITH PUBLIC OFFICER',
#        'SEX OFFENSE', 'BURGLARY', 'NARCOTICS', 'LIQUOR LAW VIOLATION',
#        'CRIM SEXUAL ASSAULT', 'MOTOR VEHICLE THEFT', 'CRIMINAL DAMAGE',
#        'OFFENSE INVOLVING CHILDREN', 'CRIMINAL TRESPASS', 'ROBBERY',
#        'PUBLIC PEACE VIOLATION', 'CRIMINAL SEXUAL ASSAULT',
#        'PROSTITUTION', 'STALKING', 'HOMICIDE', 'KIDNAPPING', 'ARSON',
#        'CONCEALED CARRY LICENSE VIOLATION', 'GAMBLING', 'OBSCENITY',
#        'INTIMIDATION', 'OTHER NARCOTIC VIOLATION', 'PUBLIC INDECENCY',
#        'NON-CRIMINAL', 'HUMAN TRAFFICKING', 'RITUALISM',
#        'DOMESTIC VIOLENCE', 'NON-CRIMINAL (SUBJECT SPECIFIED)',
#        'NON - CRIMINAL'], dtype=object)

# %%
## Crime types we care:
violent_crimes = [
    'BATTERY', 'ASSAULT', 'SEX OFFENSE', 'CRIM SEXUAL ASSAULT', 'ROBBERY',
    'CRIMINAL SEXUAL ASSAULT', 'STALKING', 'HOMICIDE', 'KIDNAPPING',
    'INTIMIDATION', 'DOMESTIC VIOLENCE', 'WEAPONS VIOLATION'
]

property_crimes = [
    'THEFT', 'BURGLARY', 'MOTOR VEHICLE THEFT', 'CRIMINAL DAMAGE',
    'ARSON', 'CRIMINAL TRESPASS'
]

# %%
violent_crime_df = crime_df[crime_df["Primary Type"].isin(violent_crimes)]
property_crime_df = crime_df[crime_df["Primary Type"].isin(property_crimes)]

# %%
print(f"shape of violent crime df: {violent_crime_df.shape}")
print(f"shape of property crime df: {property_crime_df.shape}")
# Out:
# shape of violent crime df: (2534377, 22)
# shape of property crime df: (3708663, 22)

# %%
violent_crime_df["Date"] = pd.to_datetime(violent_crime_df["Date"])
property_crime_df["Date"] = pd.to_datetime(property_crime_df["Date"])
# Out:
# <ipython-input-25-9ccdba4391fc>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   violent_crimes_df["Date"] = pd.to_datetime(violent_crimes_df["Date"])
# <ipython-input-25-9ccdba4391fc>:2: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   property_crime_df["Date"] = pd.to_datetime(property_crime_df["Date"])
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-25-9ccdba4391fc> in <cell line: 2>()
#       1 violent_crimes_df["Date"] = pd.to_datetime(violent_crimes_df["Date"])
# ...

# %%
violent_crimes_by_month = violent_crime_df.groupby(pd.Grouper(key='Date', freq='M')).size().reset_index(name='NumberOfIncident')
violent_crimes_by_month['Date'] = violent_crimes_by_month['Date'].dt.strftime('%Y-%m')

property_crimes_by_month = property_crime_df.groupby(pd.Grouper(key='Date', freq='M')).size().reset_index(name='NumberOfIncident')
property_crimes_by_month['Date'] = property_crimes_by_month['Date'].dt.strftime('%Y-%m')

# %%
violent_crimes_by_month.to_csv("/content/drive/MyDrive/MADS Capstone Team 23/Data/processed/chicago_violent_crimes_by_month.csv", index=False)
property_crimes_by_month.to_csv("/content/drive/MyDrive/MADS Capstone Team 23/Data/processed/chicago_property_crimes_by_month.csv", index=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-28-5252615e3b8a> in <cell line: 1>()
# ----> 1 violent_crimes_by_month.to_csv("/content/drive/MyDrive/MADS Capstone Team 23/Data/processed/chicago_violent_crimes_by_month.csv", index=False)
#       2 property_crimes_by_month.to_csv("/content/drive/MyDrive/MADS Capstone Team 23/Data/processed/chicago_property_crimes_by_month.csv", index=False)
#
# NameError: name 'violent_crimes_by_month' is not defined

# %% [markdown]
# ## Get Population Data and Calcualte Crime Rate / 100,000 people

# %%
import pandas as pd

population_df = pd.read_csv("/content/drive/MyDrive/MADS Capstone Team 23/Data/raw/Population/Chicago_Population_2010-2022.csv")
violent_crimes_by_month_df = pd.read_csv("/content/drive/MyDrive/MADS Capstone Team 23/Data/processed/chicago_violent_crimes_by_month.csv")
property_crimes_by_month_df = pd.read_csv("/content/drive/MyDrive/MADS Capstone Team 23/Data/processed/chicago_property_crimes_by_month.csv")

# %%
violent_crimes_by_month_df.head(12)
# Out:
#        Date  NumberOfIncident
# 0   2001-01             11172
# 1   2001-02             10088
# 2   2001-03             12906
# 3   2001-04             13392
# 4   2001-05             14403
# 5   2001-06             14144
# 6   2001-07             14988
# 7   2001-08             14179
# 8   2001-09             13668
# 9   2001-10             13557
# 10  2001-11             12129
# 11  2001-12             11309

# %%
violent_crimes_by_year = violent_crimes_by_month_df.groupby(violent_crimes_by_month_df['Date'].str[:4]).agg(
    {'NumberOfIncident': 'sum'}).reset_index()
violent_crimes_by_year.columns = ['Year', 'NumberOfIncident']

property_crimes_by_year = property_crimes_by_month_df.groupby(property_crimes_by_month_df['Date'].str[:4]).agg(
    {'NumberOfIncident': 'sum'}).reset_index()
property_crimes_by_year.columns = ['Year', 'NumberOfIncident']
