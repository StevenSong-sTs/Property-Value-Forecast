# %% [markdown]
# # Los Angeles Crime Data Processing

# %% [markdown]
# ## Process 2010 - 2019

# %%
import pandas as pd

crime_df_2010_2019 = pd.read_csv("/content/drive/MyDrive/MADS Capstone Team 23/Data/raw/CrimeData/LosAngeles/LosAngles-CrimeData-2010-2019.csv")
crime_df_2020_2024 = pd.read_csv("/content/drive/MyDrive/MADS Capstone Team 23/Data/raw/CrimeData/LosAngeles/LosAngles-CrimeData-2020-Present.csv")

# %%
crime_df_2010_2019.head(2)
# Out:
#       DR_NO               Date Rptd                DATE OCC  TIME OCC  AREA   \
# 0   1307355  02/20/2010 12:00:00 AM  02/20/2010 12:00:00 AM      1350     13
# 1  11401303  09/13/2010 12:00:00 AM  09/12/2010 12:00:00 AM        45     14
#
#   AREA NAME  Rpt Dist No  Part 1-2  Crm Cd  \
# 0    Newton         1385         2     900
# 1   Pacific         1485         2     740
#
#                                          Crm Cd Desc  ... Status  \
# 0                           VIOLATION OF COURT ORDER  ...     AA
# 1  VANDALISM - FELONY ($400 & OVER, ALL CHURCH VA...  ...     IC
#
#     Status Desc Crm Cd 1 Crm Cd 2  Crm Cd 3 Crm Cd 4  \
# 0  Adult Arrest    900.0      NaN       NaN      NaN
# 1   Invest Cont    740.0      NaN       NaN      NaN
#
#                                  LOCATION                     Cross Street  \
# 0  300 E  GAGE                         AV                              NaN
# 1         SEPULVEDA                    BL  MANCHESTER                   AV
#
# ...

# %%
crime_df_2010_2019.columns
# Out:
# Index(['DR_NO', 'Date Rptd', 'DATE OCC', 'TIME OCC', 'AREA ', 'AREA NAME',
#        'Rpt Dist No', 'Part 1-2', 'Crm Cd', 'Crm Cd Desc', 'Mocodes',
#        'Vict Age', 'Vict Sex', 'Vict Descent', 'Premis Cd', 'Premis Desc',
#        'Weapon Used Cd', 'Weapon Desc', 'Status', 'Status Desc', 'Crm Cd 1',
#        'Crm Cd 2', 'Crm Cd 3', 'Crm Cd 4', 'LOCATION', 'Cross Street', 'LAT',
#        'LON'],
#       dtype='object')

# %%
crime_df_2010_2019["Crm Cd Desc"].unique()
# Out:
# array(['VIOLATION OF COURT ORDER',
#        'VANDALISM - FELONY ($400 & OVER, ALL CHURCH VANDALISMS)',
#        'OTHER MISCELLANEOUS CRIME', 'RAPE, ATTEMPTED',
#        'SHOPLIFTING - PETTY THEFT ($950 & UNDER)',
#        'BURGLARY FROM VEHICLE',
#        'ASSAULT WITH DEADLY WEAPON, AGGRAVATED ASSAULT',
#        'THEFT-GRAND ($950.01 & OVER)EXCPT,GUNS,FOWL,LIVESTK,PROD',
#        'BATTERY - SIMPLE ASSAULT', 'ROBBERY', 'BOMB SCARE',
#        'CHILD NEGLECT (SEE 300 W.I.C.)',
#        'INTIMATE PARTNER - AGGRAVATED ASSAULT',
#        'INTIMATE PARTNER - SIMPLE ASSAULT',
#        'THEFT PLAIN - PETTY ($950 & UNDER)',
#        'CRIMINAL THREATS - NO WEAPON DISPLAYED', 'ATTEMPTED ROBBERY',
#        'VANDALISM - MISDEAMEANOR ($399 OR UNDER)', 'BURGLARY', 'ARSON',
#        'RAPE, FORCIBLE', 'BRANDISH WEAPON',
#        'THROWING OBJECT AT MOVING VEHICLE',
#        'SHOPLIFTING-GRAND THEFT ($950.01 & OVER)',
#        'CHILD ABUSE (PHYSICAL) - SIMPLE ASSAULT',
# ...

# %%
violent_crimes = [
    'RAPE, ATTEMPTED',
    'ASSAULT WITH DEADLY WEAPON, AGGRAVATED ASSAULT',
    'BATTERY - SIMPLE ASSAULT',
    'ROBBERY',
    'ATTEMPTED ROBBERY',
    'RAPE, FORCIBLE',
    'CHILD ABUSE (PHYSICAL) - SIMPLE ASSAULT',
    'KIDNAPPING - GRAND ATTEMPT',
    'CRIMINAL HOMICIDE',
    'KIDNAPPING',
    'BATTERY WITH SEXUAL CONTACT',
    'CHILD ABUSE (PHYSICAL) - AGGRAVATED ASSAULT',
    'OTHER ASSAULT',
    'INTIMATE PARTNER - AGGRAVATED ASSAULT',
    'INTIMATE PARTNER - SIMPLE ASSAULT',
    'ASSAULT WITH DEADLY WEAPON ON POLICE OFFICER',
    'SODOMY/SEXUAL CONTACT B/W PENIS OF ONE PERS TO ANUS OTH',
    'ORAL COPULATION',
    'BATTERY POLICE (SIMPLE)',
    'BATTERY ON A FIREFIGHTER',
    'CHILD ABUSE (PHYSICAL) - AGGRAVATED ASSAULT',
    'MANSLAUGHTER, NEGLIGENT',
    'SEXUAL PENETRATION W/FOREIGN OBJECT',
    'HUMAN TRAFFICKING - COMMERCIAL SEX ACTS',
    'HUMAN TRAFFICKING - INVOLUNTARY SERVITUDE',
    'CHILD PORNOGRAPHY',
    'INCEST (SEXUAL ACTS BETWEEN BLOOD RELATIVES)'
]

property_crimes = [
    'VANDALISM - FELONY ($400 & OVER, ALL CHURCH VANDALISMS)',
    'SHOPLIFTING - PETTY THEFT ($950 & UNDER)',
    'BURGLARY FROM VEHICLE',
    'THEFT-GRAND ($950.01 & OVER)EXCPT,GUNS,FOWL,LIVESTK,PROD',
    'THEFT PLAIN - PETTY ($950 & UNDER)',
    'BURGLARY',
    'ARSON',
    'SHOPLIFTING-GRAND THEFT ($950.01 & OVER)',
    'VEHICLE - STOLEN',
    'THEFT, PERSON',
    'VEHICLE - ATTEMPT STOLEN',
    'BURGLARY FROM VEHICLE, ATTEMPTED',
    'BURGLARY, ATTEMPTED',
    'PICKPOCKET',
    'EMBEZZLEMENT, GRAND THEFT ($950.01 & OVER)',
    'EMBEZZLEMENT, PETTY THEFT ($950 & UNDER)',
    'THEFT OF IDENTITY',
    'THEFT FROM MOTOR VEHICLE - PETTY ($950 & UNDER)',
    'THEFT FROM MOTOR VEHICLE - GRAND ($950.01 AND OVER)',
    'THEFT FROM MOTOR VEHICLE - ATTEMPT',
    'DEFRAUDING INNKEEPER/THEFT OF SERVICES, $950 & UNDER',
    'DEFRAUDING INNKEEPER/THEFT OF SERVICES, OVER $950.01',
    'PURSE SNATCHING',
    'PURSE SNATCHING - ATTEMPT',
    'BUNCO, PETTY THEFT',
    'BUNCO, GRAND THEFT',
    'BUNCO, ATTEMPT',
    'THEFT, COIN MACHINE - PETTY ($950 & UNDER)',
    'THEFT, COIN MACHINE - GRAND ($950.01 & OVER)',
    'THEFT, COIN MACHINE - ATTEMPT',
    'PETTY THEFT - AUTO REPAIR',
    'GRAND THEFT / AUTO REPAIR',
    'BIKE - STOLEN',
    'BIKE - ATTEMPTED STOLEN',
    'DOCUMENT FORGERY / STOLEN FELONY',
    'CREDIT CARDS, FRAUD USE ($950.01 & OVER)',
    'CREDIT CARDS, FRAUD USE ($950 & UNDER',
    'DOCUMENT WORTHLESS ($200.01 & OVER)',
    'DOCUMENT WORTHLESS ($200 & UNDER)',
    'COUNTERFEIT',
    'DISHONEST EMPLOYEE - GRAND THEFT',
    'DISHONEST EMPLOYEE - PETTY THEFT',
    'DISHONEST EMPLOYEE ATTEMPTED THEFT',
    'SHOPLIFTING - ATTEMPT',
    'GRAND THEFT / INSURANCE FRAUD',
    'BOAT - STOLEN',
    'TILL TAP - PETTY ($950 & UNDER)',
    'TILL TAP - GRAND THEFT ($950.01 & OVER)',
    'TILL TAP - ATTEMPT'
]

# %%
violent_crime_df = crime_df_2010_2019[crime_df_2010_2019["Crm Cd Desc"].isin(violent_crimes)]
property_crime_df = crime_df_2010_2019[crime_df_2010_2019["Crm Cd Desc"].isin(property_crimes)]

# %%
violent_crime_df["Date Rptd"] = pd.to_datetime(violent_crime_df["Date Rptd"])
property_crime_df["Date Rptd"] = pd.to_datetime(property_crime_df["Date Rptd"])
# Out:
# <ipython-input-11-cf80ae20c222>:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   violent_crime_df["Date Rptd"] = pd.to_datetime(violent_crime_df["Date Rptd"])
# <ipython-input-11-cf80ae20c222>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   violent_crime_df["Date Rptd"] = pd.to_datetime(violent_crime_df["Date Rptd"])
# <ipython-input-11-cf80ae20c222>:2: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
# ...

# %%
violent_crime_df.rename(columns={"Date Rptd": "Date"}, inplace=True)
property_crime_df.rename(columns={"Date Rptd": "Date"}, inplace=True)
# Out:
# <ipython-input-12-6439f39479fc>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   violent_crime_df.rename(columns={"Date Rptd": "Date"}, inplace=True)
# <ipython-input-12-6439f39479fc>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   property_crime_df.rename(columns={"Date Rptd": "Date"}, inplace=True)

# %%
violent_crimes_by_month_2010_2019 = violent_crime_df.groupby(pd.Grouper(key='Date', freq='M')).size().reset_index(name='NumberOfIncident')
violent_crimes_by_month_2010_2019['Date'] = violent_crimes_by_month_2010_2019['Date'].dt.strftime('%Y-%m')

property_crimes_by_month_2010_2019 = property_crime_df.groupby(pd.Grouper(key='Date', freq='M')).size().reset_index(name='NumberOfIncident')
property_crimes_by_month_2010_2019['Date'] = property_crimes_by_month_2010_2019['Date'].dt.strftime('%Y-%m')

# %% [markdown]
# ## Process 2020-2024

# %%
crime_df_2020_2024.head(2)
# Out:
#        DR_NO               Date Rptd                DATE OCC  TIME OCC  AREA  \
# 0  190326475  03/01/2020 12:00:00 AM  03/01/2020 12:00:00 AM      2130     7
# 1  200106753  02/09/2020 12:00:00 AM  02/08/2020 12:00:00 AM      1800     1
#
#   AREA NAME  Rpt Dist No  Part 1-2  Crm Cd            Crm Cd Desc  ... Status  \
# 0  Wilshire          784         1     510       VEHICLE - STOLEN  ...     AA
# 1   Central          182         1     330  BURGLARY FROM VEHICLE  ...     IC
#
#     Status Desc Crm Cd 1 Crm Cd 2  Crm Cd 3 Crm Cd 4  \
# 0  Adult Arrest    510.0    998.0       NaN      NaN
# 1   Invest Cont    330.0    998.0       NaN      NaN
#
#                                   LOCATION Cross Street      LAT       LON
# 0  1900 S  LONGWOOD                     AV          NaN  34.0375 -118.3506
# 1  1000 S  FLOWER                       ST          NaN  34.0444 -118.2628
#
# [2 rows x 28 columns]

# %%
crime_df_2020_2024["Crm Cd Desc"].unique()
# Out:
# array(['VEHICLE - STOLEN', 'BURGLARY FROM VEHICLE', 'BIKE - STOLEN',
#        'SHOPLIFTING-GRAND THEFT ($950.01 & OVER)', 'THEFT OF IDENTITY',
#        'BATTERY - SIMPLE ASSAULT',
#        'SODOMY/SEXUAL CONTACT B/W PENIS OF ONE PERS TO ANUS OTH',
#        'CRM AGNST CHLD (13 OR UNDER) (14-15 & SUSP 10 YRS OLDER)',
#        'SEX,UNLAWFUL(INC MUTUAL CONSENT, PENETRATION W/ FRGN OBJ',
#        'ASSAULT WITH DEADLY WEAPON, AGGRAVATED ASSAULT',
#        'LETTERS, LEWD  -  TELEPHONE CALLS, LEWD',
#        'THEFT-GRAND ($950.01 & OVER)EXCPT,GUNS,FOWL,LIVESTK,PROD',
#        'CRIMINAL THREATS - NO WEAPON DISPLAYED',
#        'EMBEZZLEMENT, GRAND THEFT ($950.01 & OVER)',
#        'THEFT FROM MOTOR VEHICLE - PETTY ($950 & UNDER)',
#        'CHILD ANNOYING (17YRS & UNDER)', 'BURGLARY', 'CONTEMPT OF COURT',
#        'THEFT PLAIN - PETTY ($950 & UNDER)',
#        'INTIMATE PARTNER - SIMPLE ASSAULT', 'LEWD CONDUCT',
#        'THEFT PLAIN - ATTEMPT',
# ...

# %%
violent_crime = [
    'BATTERY - SIMPLE ASSAULT',
    'SODOMY/SEXUAL CONTACT B/W PENIS OF ONE PERS TO ANUS OTH',
    'ASSAULT WITH DEADLY WEAPON, AGGRAVATED ASSAULT',
    'RAPE, FORCIBLE',
    'RAPE, ATTEMPTED',
    'CHILD ABUSE (PHYSICAL) - SIMPLE ASSAULT',
    'INTIMATE PARTNER - SIMPLE ASSAULT',
    'BATTERY WITH SEXUAL CONTACT',
    'INTIMATE PARTNER - AGGRAVATED ASSAULT',
    'ORAL COPULATION',
    'ASSAULT WITH DEADLY WEAPON ON POLICE OFFICER',
    'CHILD ABUSE (PHYSICAL) - AGGRAVATED ASSAULT',
    'ATTEMPTED ROBBERY',
    'ROBBERY',
    'THREATENING PHONE CALLS/LETTERS',
    'SEXUAL PENETRATION W/FOREIGN OBJECT',
    'CHILD NEGLECT (SEE 300 W.I.C.)',
    'KIDNAPPING - GRAND ATTEMPT',
    'KIDNAPPING',
    'CRIMINAL HOMICIDE',
    'HUMAN TRAFFICKING - INVOLUNTARY SERVITUDE',
    'HUMAN TRAFFICKING - COMMERCIAL SEX ACTS',
    'CHILD PORNOGRAPHY',
    'BATTERY POLICE (SIMPLE)',
    'BATTERY ON A FIREFIGHTER',
    'CRUELTY TO ANIMALS',
    'MANSLAUGHTER, NEGLIGENT',
    'LEWD/LASCIVIOUS ACTS WITH CHILD',
    'INCEST (SEXUAL ACTS BETWEEN BLOOD RELATIVES)'
]

property_crime = [
    'VEHICLE - STOLEN',
    'BURGLARY FROM VEHICLE',
    'BIKE - STOLEN',
    'SHOPLIFTING-GRAND THEFT ($950.01 & OVER)',
    'THEFT OF IDENTITY',
    'THEFT-GRAND ($950.01 & OVER)EXCPT,GUNS,FOWL,LIVESTK,PROD',
    'EMBEZZLEMENT, GRAND THEFT ($950.01 & OVER)',
    'THEFT FROM MOTOR VEHICLE - PETTY ($950 & UNDER)',
    'BURGLARY',
    'THEFT PLAIN - PETTY ($950 & UNDER)',
    'THEFT PLAIN - ATTEMPT',
    'THEFT FROM MOTOR VEHICLE - GRAND ($950.01 AND OVER)',
    'BUNCO, GRAND THEFT',
    'SHOPLIFTING - PETTY THEFT ($950 & UNDER)',
    'VANDALISM - FELONY ($400 & OVER, ALL CHURCH VANDALISMS)',
    'DOCUMENT FORGERY / STOLEN FELONY',
    'CREDIT CARDS, FRAUD USE ($950.01 & OVER)',
    'PICKPOCKET',
    'ARSON',
    'BUNCO, ATTEMPT',
    'BURGLARY, ATTEMPTED',
    'CREDIT CARDS, FRAUD USE ($950 & UNDER',
    'EMBEZZLEMENT, PETTY THEFT ($950 & UNDER)',
    'DISHONEST EMPLOYEE - GRAND THEFT',
    'THEFT FROM PERSON - ATTEMPT',
    'PURSE SNATCHING',
    'VEHICLE - ATTEMPT STOLEN',
    'BURGLARY FROM VEHICLE, ATTEMPTED',
    'THEFT, PERSON',
    'PURSE SNATCHING - ATTEMPT',
    'THEFT FROM MOTOR VEHICLE - ATTEMPT',
    'DISHONEST EMPLOYEE - PETTY THEFT',
    'SHOPLIFTING - ATTEMPT',
    'COUNTERFEIT',
    'DEFRAUDING INNKEEPER/THEFT OF SERVICES, $950 & UNDER',
    'DEFRAUDING INNKEEPER/THEFT OF SERVICES, OVER $950.01',
    'BOAT - STOLEN',
    'THEFT, COIN MACHINE - PETTY ($950 & UNDER)',
    'DOCUMENT WORTHLESS ($200.01 & OVER)',
    'THEFT, COIN MACHINE - ATTEMPT',
    'TILL TAP - GRAND THEFT ($950.01 & OVER)',
    'GRAND THEFT / AUTO REPAIR',
    'GRAND THEFT / INSURANCE FRAUD',
    'THEFT, COIN MACHINE - GRAND ($950.01 & OVER)',
    'PICKPOCKET, ATTEMPT',
    'DOCUMENT WORTHLESS ($200 & UNDER)',
    'TILL TAP - PETTY ($950 & UNDER)',
    'TRESPASSING',
    'SHOPLIFTING - PETTY THEFT ($950 & UNDER)'
]

# %%
violent_crime_df_2020_2024 = crime_df_2020_2024[crime_df_2020_2024["Crm Cd Desc"].isin(violent_crimes)]
property_crime_df_2020_2024 = crime_df_2020_2024[crime_df_2020_2024["Crm Cd Desc"].isin(property_crimes)]

# %%
violent_crime_df_2020_2024["Date Rptd"] = pd.to_datetime(violent_crime_df_2020_2024["Date Rptd"])
property_crime_df_2020_2024["Date Rptd"] = pd.to_datetime(property_crime_df_2020_2024["Date Rptd"])
# Out:
# <ipython-input-25-bcd076d8c58d>:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   violent_crime_df_2020_2024["Date Rptd"] = pd.to_datetime(violent_crime_df_2020_2024["Date Rptd"])
# <ipython-input-25-bcd076d8c58d>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   violent_crime_df_2020_2024["Date Rptd"] = pd.to_datetime(violent_crime_df_2020_2024["Date Rptd"])
# <ipython-input-25-bcd076d8c58d>:2: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
# ...

# %%
violent_crime_df_2020_2024.rename(columns={"Date Rptd": "Date"}, inplace=True)
property_crime_df_2020_2024.rename(columns={"Date Rptd": "Date"}, inplace=True)
# Out:
# <ipython-input-27-d6b327d3824a>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   violent_crime_df_2020_2024.rename(columns={"Date Rptd": "Date"}, inplace=True)
# <ipython-input-27-d6b327d3824a>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   property_crime_df_2020_2024.rename(columns={"Date Rptd": "Date"}, inplace=True)

# %%
violent_crimes_by_month_2020_2024 = violent_crime_df_2020_2024.groupby(pd.Grouper(key='Date', freq='M')).size().reset_index(name='NumberOfIncident')
violent_crimes_by_month_2020_2024['Date'] = violent_crimes_by_month_2020_2024['Date'].dt.strftime('%Y-%m')

property_crimes_by_month_2020_2024 = property_crime_df_2020_2024.groupby(pd.Grouper(key='Date', freq='M')).size().reset_index(name='NumberOfIncident')
property_crimes_by_month_2020_2024['Date'] = property_crimes_by_month_2020_2024['Date'].dt.strftime('%Y-%m')

# %%
combined_violent_crimes = pd.merge(violent_crimes_by_month_2010_2019, violent_crimes_by_month_2020_2024, on='Date', how='outer')
combined_violent_crimes['NumberOfIncident_y'] = combined_violent_crimes['NumberOfIncident_y'].fillna(0)
combined_violent_crimes['NumberOfIncident_x'] = combined_violent_crimes['NumberOfIncident_x'].fillna(0)
combined_violent_crimes['NumberOfIncident'] = combined_violent_crimes['NumberOfIncident_x'] + combined_violent_crimes['NumberOfIncident_y']
combined_violent_crimes = combined_violent_crimes.drop(['NumberOfIncident_x', 'NumberOfIncident_y'], axis=1)

# %%
combined_violent_crimes
# Out:
#         Date  NumberOfIncident
# 0    2010-01            4444.0
# 1    2010-02            4094.0
# 2    2010-03            4685.0
# 3    2010-04            4615.0
# 4    2010-05            4955.0
# ..       ...               ...
# 169  2024-02            4418.0
# 170  2024-03            3849.0
# 171  2024-04            2814.0
# 172  2024-05            1091.0
# 173  2024-06             149.0
#
# [174 rows x 2 columns]

# %%
combined_property_crimes = pd.merge(property_crimes_by_month_2010_2019, property_crimes_by_month_2020_2024, on='Date', how='outer')
combined_property_crimes['NumberOfIncident_y'] = combined_property_crimes['NumberOfIncident_y'].fillna(0)
combined_property_crimes['NumberOfIncident_x'] = combined_property_crimes['NumberOfIncident_x'].fillna(0)
combined_property_crimes['NumberOfIncident'] = combined_property_crimes['NumberOfIncident_x'] + combined_property_crimes['NumberOfIncident_y']
combined_property_crimes = combined_property_crimes.drop(['NumberOfIncident_x', 'NumberOfIncident_y'], axis=1)

combined_property_crimes
# Out:
#         Date  NumberOfIncident
# 0    2010-01            8534.0
# 1    2010-02            8399.0
# 2    2010-03            9716.0
# 3    2010-04            9444.0
# 4    2010-05            9377.0
# ..       ...               ...
# 169  2024-02           10967.0
# 170  2024-03           10860.0
# 171  2024-04            9208.0
# 172  2024-05            7715.0
# 173  2024-06            5280.0
#
# [174 rows x 2 columns]

# %%
combined_violent_crimes.to_csv("/content/drive/MyDrive/MADS Capstone Team 23/Data/processed/losangeles_violent_crimes_by_month.csv", index=False)
combined_property_crimes.to_csv("/content/drive/MyDrive/MADS Capstone Team 23/Data/processed/losangeles_property_crimes_by_month.csv", index=False)
